# %% [markdown]
# 1. Made the connexion to Google Drive

# %%
from google.colab import drive 
drive.mount('/content/drive')

# %% [markdown]
# 2. Choose Your Torrent Client
#
# (Write in order) :
#
# *   QBittorrent
# *   List item

# %% [markdown]
# **QBITTORRENT**
#
# Remove the HTTPS to HTTP
#
# For AutoSync into Drive:
# You need to configure the destination folder like that and activate imcomplet dir :
# ![image.png](data:image/png;base64,...)
#
# (For Your personnal drive : /content/drive/My Drive/"folder"
# For a shared drive : /content/drive/Shared drives/<shared drive name>/"folder"/)

# %%
import os
import time
import pathlib 
import urllib.request
from IPython.display import clear_output

#####################################
USE_FREE_TOKEN = False 
NgrokTOKEN = "YOUR_API_KEY" # @param {type:"string"}
HOME = os.path.expanduser("~")
 
if not os.path.exists(f"{HOME}/.ipython/ttmg.py"):
    hCode = "https://raw.githubusercontent.com/Pavithran-R/" \
                "Colab-SimpleTorrent/master/res/ttmg.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ttmg.py")
 
from ttmg import (
    ngrok
)

# !apt install qbittorrent-nox
 
# START_SERVER
clear_output()
Server = ngrok(
    NgrokTOKEN, USE_FREE_TOKEN, [['simple-torrent', 4444, 'http'], 
    ['peerflix-server', 4445, 'http']], 'us', 
    [f"{HOME}/.ngrok2/ngrok01.yml", 4040]
).start('simple-torrent')

#Start torrent
# !qbittorrent-nox --webui-port=4444

# %% [markdown]
# **DELUGE**
#
# For AutoSync into Drive:
# You need to configure the destination folder like that :
# ![image.png](data:image/png;base64,...)
#
# (For Your personnal drive : /content/drive/My Drive/"folder"
# For a shared drive : /content/drive/Shared drives/<shared drive name>/"folder"/)

# %%
import os
import time
import pathlib 
import urllib.request
from IPython.display import clear_output

#####################################
USE_FREE_TOKEN = False 
NgrokTOKEN = "YOUR-API-KEY" # @param {type:"string"}
HOME = os.path.expanduser("~")
 
if not os.path.exists(f"{HOME}/.ipython/ttmg.py"):
    hCode = "https://raw.githubusercontent.com/Pavithran-R/" \
                "Colab-SimpleTorrent/master/res/ttmg.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ttmg.py")
 
from ttmg import (
    ngrok
)

# !apt install deluged deluge-web
 
# START_SERVER
clear_output()
Server = ngrok(
    NgrokTOKEN, USE_FREE_TOKEN, [['simple-torrent', 8112, 'http'], 
    ['peerflix-server', 4445, 'http']], 'us', 
    [f"{HOME}/.ngrok2/ngrok01.yml", 4040]
).start('simple-torrent')

#Start torrent
print("The default password is 'deluge', \ntape enter when you want to kill it (or reset the contenair)")
os.system("deluged")
os.system("deluge-web")
print("The default password is 'deluge', \ntape enter when you want to kill it (or reset the contenair)")
a=input()
